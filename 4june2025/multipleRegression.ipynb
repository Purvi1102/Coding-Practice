# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
inport pandas as pd
# Out:
#   Cell In[2], line 1
#     inport pandas as pd
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_index=pd.read_csv("multi.csv")

# %%
df_index.head()
# Out:
#    year  month  interest_rate  unemployment_rate  index_price
# 0  2020      1            2.5                5.0         1100
# 1  2020      2            2.4                5.1         1120
# 2  2020      3            2.3                5.3         1090
# 3  2020      4            2.1                5.5         1050
# 4  2020      5            2.0                5.6         1020

# %%
df_index.isnull().sum()
# Out:
# year                 0
# month                0
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
#let do visualization

# %%
import seaborn as sns

# %%
sns.pairplot(df_index) # this show the relationship between the attributes of dataset(linear and non-linear)

# %%
df_index.corr()
# Out:
#                            year         month  interest_rate  \
# year               1.000000e+00  7.185551e-14      -0.402694
# month              7.185551e-14  1.000000e+00       0.019649
# interest_rate     -4.026936e-01  1.964944e-02       1.000000
# unemployment_rate -5.699764e-01  2.085900e-02      -0.444706
# index_price        1.096176e-01  6.418550e-02       0.831347
#
#                    unemployment_rate  index_price
# year                       -0.569976     0.109618
# month                       0.020859     0.064186
# interest_rate              -0.444706     0.831347
# unemployment_rate           1.000000    -0.783596
# index_price                -0.783596     1.000000

# %%
 X=df_index.iloc[:,:-1]
 Y=df_index.iloc[:,-1]

# %%
X.head()
# Out:
#    year  month  interest_rate  unemployment_rate
# 0  2020      1            2.5                5.0
# 1  2020      2            2.4                5.1
# 2  2020      3            2.3                5.3
# 3  2020      4            2.1                5.5
# 4  2020      5            2.0                5.6

# %%
Y
# Out:
# 0     1100
# 1     1120
# 2     1090
# 3     1050
# 4     1020
# 5     1000
# 6     1010
# 7     1030
# 8     1060
# 9     1080
# 10    1110
# 11    1150
# Name: index_price, dtype: int64

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=42   )

# %%
import seaborn as sns

# %%
sns.regplot(x=df_index['interest_rate'], y=df_index['unemployment_rate'])
plt.show()

# %%
pip install standardscaler
# Out:
# Collecting standardscaler
#   Downloading StandardScaler-0.5.tar.gz (2.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from standardscaler) (1.26.4)
# Requirement already satisfied: pandas in c:\users\asus\anaconda3\lib\site-packages (from standardscaler) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\asus\anaconda3\lib\site-packages (from standardscaler) (1.4.2)
# Collecting scikit-elm (from standardscaler)
#   Downloading scikit_elm-0.21a0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: dask in c:\users\asus\anaconda3\lib\site-packages (from standardscaler) (2024.5.0)
# Requirement already satisfied: click>=8.1 in c:\users\asus\anaconda3\lib\site-packages (from dask->standardscaler) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\asus\anaconda3\lib\site-packages (from dask->standardscaler) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\asus\anaconda3\lib\site-packages (from dask->standardscaler) (2024.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from dask->standardscaler) (23.2)
# Requirement already satisfied: partd>=1.2.0 in c:\users\asus\anaconda3\lib\site-packages (from dask->standardscaler) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\asus\anaconda3\lib\site-packages (from dask->standardscaler) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\asus\anaconda3\lib\site-packages (from dask->standardscaler) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\lib\site-packages (from pandas->standardscaler) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas->standardscaler) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\anaconda3\lib\site-packages (from pandas->standardscaler) (2023.3)
# Requirement already satisfied: scipy in c:\users\asus\anaconda3\lib\site-packages (from scikit-elm->standardscaler) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn->standardscaler) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn->standardscaler) (2.2.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from click>=8.1->dask->standardscaler) (0.4.6)
# Requirement already satisfied: locket in c:\users\asus\anaconda3\lib\site-packages (from partd>=1.2.0->dask->standardscaler) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->standardscaler) (1.16.0)
# Downloading scikit_elm-0.21a0-py3-none-any.whl (30 kB)
# Building wheels for collected packages: standardscaler
#   Building wheel for standardscaler (setup.py): started
#   Building wheel for standardscaler (setup.py): finished with status 'done'
#   Created wheel for standardscaler: filename=StandardScaler-0.5-py3-none-any.whl size=2608 sha256=0e772f37ec2cf223455f6d872f1cd49f5268d2375c199684b869f900ddd900cb
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\fe\cf\ba\03416e6fb72a0105069c33d9bf5a2ec1af9a41fe57fa7ec554
# Successfully built standardscaler
# Installing collected packages: scikit-elm, standardscaler
# Successfully installed scikit-elm-0.21a0 standardscaler-0.5
# Note: you may need to restart the kernel to use updated packages.

# %%
 from sklearn.preprocessing import StandardScaler
