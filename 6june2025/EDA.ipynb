# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_copy=pd.read_csv('fire_dataset_200_rows.csv')

# %%
df_copy.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           30  63  11   6.4  63.1  2.9  14.5  0.4  4.5
# 1    2      6  2012           27  46  28  13.6  73.5  9.1  13.2  0.4  3.3
# 2    3      6  2012           34  88  26   1.7  53.1  2.8  15.0  2.1  1.1
# 3    4      6  2012           31  70  29   7.4  33.3  2.7   9.2  1.3  4.7
# 4    5      6  2012           28  76  19   0.2  43.4  1.3  12.9  0.6  3.8
#
#    FWI   Classes  Region
# 0  0.3  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.9  not fire       1
# 4  0.6  not fire       0

# %%
df_copy = df.drop(['day', 'month', 'year'], axis=1, errors='ignore')  # Use 'ignore' to avoid KeyError

# %%
print(df.columns.tolist())
# Out:
# ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region']

# %%
for col in df.columns:
    print(f"'{col}'")
# Out:
# 'Temperature'
# 'RH'
# 'Ws'
# 'Rain'
# 'FFMC'
# 'DMC'
# 'DC'
# 'ISI'
# 'BUI'
# 'FWI'
# 'Classes'
# 'Region'

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           30  63  11   6.4  63.1  2.9  14.5  0.4  4.5  0.3        0       0
# 1           27  46  28  13.6  73.5  9.1  13.2  0.4  3.3  0.4        0       0
# 2           34  88  26   1.7  53.1  2.8  15.0  2.1  1.1  0.1        0       0
# 3           31  70  29   7.4  33.3  2.7   9.2  1.3  4.7  0.9        0       1
# 4           28  76  19   0.2  43.4  1.3  12.9  0.6  3.8  0.6        0       0

# %%
df_copy['Classes'].head()
print(df_copy['Classes'].dtype)
# Out:
# int32

# %%
df_copy['Classes'] = np.where(df_copy['Classes'].astype(str).str.contains('not fire'), 0, 1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           30  63  11   6.4  63.1  2.9  14.5  0.4  4.5  0.3        1       0
# 1           27  46  28  13.6  73.5  9.1  13.2  0.4  3.3  0.4        1       0
# 2           34  88  26   1.7  53.1  2.8  15.0  2.1  1.1  0.1        1       0
# 3           31  70  29   7.4  33.3  2.7   9.2  1.3  4.7  0.9        1       1
# 4           28  76  19   0.2  43.4  1.3  12.9  0.6  3.8  0.6        1       0

# %%
df_copy['Classes'].value_counts(normalize='True')*100
# Out:
# Classes
# 1    100.0
# Name: proportion, dtype: float64

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000  0.031806 -0.025103 -0.050844  0.050709  0.113891
# RH              0.031806  1.000000  0.030168  0.004210  0.069053 -0.007300
# Ws             -0.025103  0.030168  1.000000 -0.040256 -0.001707 -0.050643
# Rain           -0.050844  0.004210 -0.040256  1.000000 -0.011383 -0.010054
# FFMC            0.050709  0.069053 -0.001707 -0.011383  1.000000  0.034811
# DMC             0.113891 -0.007300 -0.050643 -0.010054  0.034811  1.000000
# DC             -0.138192 -0.085310  0.015846 -0.039413  0.189613 -0.003129
# ISI             0.081315  0.064205 -0.034816  0.013862 -0.051217  0.059580
# BUI            -0.035439  0.024071  0.036524  0.083668 -0.024692 -0.078631
# FWI            -0.033022  0.084962 -0.056420  0.171760 -0.057352  0.046126
# Classes              NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
import seaborn as sns ## this tell how every feature is correlated with every other feature
sns.heatmap(df.corr())
# Out:
# <Axes: >
